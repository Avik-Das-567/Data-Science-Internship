# %% [markdown]
# **HackerRank Link:** https://www.hackerrank.com/domains/python?filters%5Bsubdomains%5D%5B%5D=py-introduction
#
# ---

# %% [markdown]
# **1. Say "Hello World" with Python**

# %%
if __name__ == '__main__':
    print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **2. Arithmetic Operators**

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())

    print(a + b)
    print(a - b)
    print(a * b)
# Out:
# 3
# 2
# 5
# 1
# 6

# %% [markdown]
# **3. Python: Division**

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())

    print(a//b)
    print(a/b)
# Out:
# 4
# 3
# 1
# 1.3333333333333333

# %% [markdown]
# **4. Loops**

# %%
if __name__ == '__main__':
    n = int(input())

    for i in range(n):
        print(i * i)
# Out:
# 5
# 0
# 1
# 4
# 9
# 16

# %% [markdown]
# **5. Write a function**

# %%
def is_leap(year):
    leap = False
    if year % 400 == 0:
        return True
    if year % 100 == 0:
        return False
    if year % 4 == 0:
        return True
    return leap

year = int(input())
print(is_leap(year))
# Out:
# 1990
# False

# %% [markdown]
# **6. Print Function**

# %%
if __name__ == '__main__':
    n = int(input())

    result = 0
    for i in range(1, n + 1):
        digits = 0
        temp = i
        while temp > 0:
            temp //= 10
            digits += 1
        result = result * (10 ** digits) + i

    print(result)
# Out:
# 5
# 12345

# %% [markdown]
# **7. Python If-Else**

# %%
if __name__ == '__main__':
    n = int(input().strip())

    if n % 2 == 1:
        print("Weird")
    elif 2 <= n <= 5:
        print("Not Weird")
    elif 6 <= n <= 20:
        print("Weird")
    else:
        print("Not Weird")
# Out:
# 24
# Not Weird
